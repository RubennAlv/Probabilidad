# %% [markdown]
# <a href="https://colab.research.google.com/github/RubennAlv/Probabilidad/blob/main/Unidad2/programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROBABILIDAD Y ESTADISTICA
#
# ##UNIDAD 2
#
# ###FACILITADOR: Jose Gabriel Rodrigues Rivas
#
# ### Alumno: Edwin Ruben Alvarado Mapula
#
# ##### **PROGRAMA 1**

# %%
import math as mt
from itertools import *
import numpy as np
nombres = ["Oscar", "Paco", "Laura", "Ruben", "Luis", "Lucy", "Alberto", "Juan","Danny"]
n=len(nombres)
r=2 #¿como agrupar?

Cn= mt.factorial(n)/(mt.factorial(r)*mt.factorial(n-r))
print("Existen ", Cn, "posibles combinaciones sin repetiion del total de ", n , "nombres", "en grupos de ", r, "en", r)
print("Aqui las combinaciones")
combinaciones_reales= list (combinations(nombres,r))

#imprime las combinaciones
for combinations in combinaciones_reales:
  print(combinations)
# Out:
# Existen  36.0 posibles combinaciones sin repetiion del total de  9 nombres en grupos de  2 en 2
# Aqui las combinaciones
# ('Oscar', 'Paco')
# ('Oscar', 'Laura')
# ('Oscar', 'Ruben')
# ('Oscar', 'Luis')
# ('Oscar', 'Lucy')
# ('Oscar', 'Alberto')
# ('Oscar', 'Juan')
# ('Oscar', 'Danny')
# ('Paco', 'Laura')
# ('Paco', 'Ruben')
# ('Paco', 'Luis')
# ('Paco', 'Lucy')
# ('Paco', 'Alberto')
# ('Paco', 'Juan')
# ('Paco', 'Danny')
# ('Laura', 'Ruben')
# ('Laura', 'Luis')
# ('Laura', 'Lucy')
# ('Laura', 'Alberto')
# ('Laura', 'Juan')
# ('Laura', 'Danny')
# ('Ruben', 'Luis')
# ('Ruben', 'Lucy')
# ('Ruben', 'Alberto')
# ('Ruben', 'Juan')
# ('Ruben', 'Danny')
# ('Luis', 'Lucy')
# ('Luis', 'Alberto')
# ('Luis', 'Juan')
# ('Luis', 'Danny')
# ('Lucy', 'Alberto')
# ('Lucy', 'Juan')
# ('Lucy', 'Danny')
# ('Alberto', 'Juan')
# ('Alberto', 'Danny')
# ('Juan', 'Danny')
