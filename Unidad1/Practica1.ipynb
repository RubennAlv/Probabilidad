# %% [markdown]
# <a href="https://colab.research.google.com/github/RubennAlv/Probabilidad/blob/main/Unidad1/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadística
#
# ## Unidad 1
#
# ###Facilitador: José Gabriel Rodriguez Rivas
# ###Alumno: Edwin Rubén Alvarado Mapula
# ###**Programa 1: Estadística básica e Histograma**

# %%
from statistics import *

# %%
#Lista de calificaciones del grupo a de probabilidad y estadística
grupoA = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(grupoA)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
#Funcion que devuelve el tipo de dato
type(grupoA)
# Out:
# list

# %%
#promedio de los datos con mean de statistics
mean(grupoA)
# Out:
# 75.33333333333333

# %%
#manual
print(sum(grupoA)/len(grupoA))
# Out:
# 75.33333333333333

# %%
#mediana con funcion
mediana = median(grupoA)
print(mediana)
# Out:
# 76.5

# %%
#moda con funcion
moda = mode(grupoA)
print(moda)
# Out:
# 70

# %%
#si hay varias modas...
multimodal = multimode(grupoA)
print(multimodal)
# Out:
# [70, 100]

# %%
#Ejemplo 2
#Definimos una variable que se llame tiempos100mts, de tipo lista, que contiene los tiempos que tardaron los 10 alumnos para correr 100 mts.
tiempos100mts=[15.10, 17.30, 18.45, 19.32, 12.5, 13.3, 17.3, 13.5, 21.4, 15.9]
print(f"el tiempo promedio es : ",  mean(tiempos100mts), "\n", "la mediana es: ", median(tiempos100mts),"\n", "la moda es: ", mode(tiempos100mts))
# Out:
# el tiempo promedio es :  16.407
#  la mediana es:  16.6
#  la moda es:  17.3

# %% [markdown]
# #Ejemplo 3: histogramma de 2 grupos
# ###1.En ste ejemplo generaremos 100 numeros aleatorios reales que representa la produccion de 100 telares

# %%
import random as rnd

fabrica1 = []
for i in range(100):
  numeroRnd = round(rnd.uniform(50, 100), 2)
  fabrica1.append(numeroRnd)
print(fabrica1)

fabrica2 = []
for i in range(100):
  numeroRnd = round(rnd.uniform(70, 100), 2)
  fabrica2.append(numeroRnd)
print(fabrica2)
# Out:
# [97.31, 91.3, 50.69, 66.97, 74.68, 93.35, 70.45, 72.15, 63.68, 94.71, 83.05, 90.41, 82.19, 87.69, 87.77, 75.1, 54.98, 75.16, 53.93, 93.44, 94.95, 52.81, 87.51, 95.54, 99.66, 51.13, 57.83, 71.2, 92.06, 92.49, 72.44, 57.07, 92.31, 58.99, 78.81, 84.35, 70.78, 90.95, 85.81, 81.49, 52.46, 67.15, 53.66, 90.7, 73.84, 95.99, 76.54, 58.92, 77.27, 95.15, 51.85, 69.15, 75.59, 76.65, 95.51, 73.66, 68.72, 72.15, 96.83, 77.41, 83.04, 79.7, 88.74, 91.49, 56.97, 70.43, 98.22, 73.94, 75.38, 93.27, 64.54, 66.3, 92.07, 55.59, 88.11, 54.41, 56.77, 81.94, 73.34, 53.3, 62.26, 72.59, 71.33, 70.38, 91.93, 51.26, 65.23, 99.78, 95.96, 94.76, 75.48, 91.93, 70.37, 53.54, 87.93, 85.79, 71.75, 68.2, 68.33, 55.76]
# [98.33, 97.24, 85.46, 81.54, 95.9, 74.62, 79.62, 84.71, 96.84, 94.21, 91.16, 89.31, 73.25, 94.88, 84.19, 80.73, 74.65, 86.03, 76.62, 76.14, 76.69, 72.79, 94.06, 84.83, 73.81, 88.76, 85.29, 78.92, 87.22, 78.44, 84.55, 84.04, 77.46, 93.22, 99.99, 79.74, 89.04, 71.02, 80.26, 70.44, 86.58, 83.68, 82.68, 98.41, 93.35, 97.85, 98.91, 77.1, 97.75, 86.09, 90.48, 78.67, 74.12, 71.76, 86.88, 99.09, 80.97, 84.78, 70.26, 91.92, 86.58, 71.05, 74.07, 99.57, 71.73, 80.54, 96.99, 94.59, 78.35, 97.05, 80.51, 95.84, 88.79, 72.16, 83.64, 92.91, 78.03, 71.82, 91.03, 71.05, 97.88, 79.54, 85.49, 79.3, 73.79, 72.87, 99.81, 92.9, 90.15, 83.69, 71.02, 85.42, 78.98, 84.51, 75.89, 82.51, 82.87, 89.0, 93.32, 83.47]

# %%
#histograma para comparar ambas fabricas
import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("produccion diaraia de la fábrica 1")
plt.hist(fabrica2)
plt.title("produccion diaraia de l fábrica 2")
# Out:
# Text(0.5, 1.0, 'produccion diaraia de l fábrica 2')

# %%
#generar una grafica diferente para cada fabrica una al lado de la otra
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
#valores de la fabrica 1
print("valores de la fabrica 1")
print(f"la media es: ", mean(fabrica1))
print(f"la mediana es: ", median(fabrica1))
print(f"la moda es: ", mode(fabrica1))
# Out:
# valores de la fabrica 1
# la media es:  76.285
# la mediana es:  75.27
# la moda es:  72.15

# %%
#valores de la fabrica 2
print("valores de la fabrica 2")
print(f"la media es: ", mean(fabrica2))
print(f"la mediana es: ", median(fabrica2))
print(f"la moda es: ", mode(fabrica2))
# Out:
# valores de la fabrica 2
# la media es:  84.5604
# la mediana es:  84.35
# la moda es:  71.02
