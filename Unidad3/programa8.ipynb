# %% [markdown]
# <a href="https://colab.research.google.com/github/RubennAlv/Probabilidad/blob/main/Unidad3/programa8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 3
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Alvarado Mapula Edwin Ruben
# ### **Programa 8**

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,6,7,8,9,10])
p=np.array([0.05,0.10,0.20,0.30,0.25,0.10])
print("Suma de probabilidades:", np.sum(p))
E=np.sum(x*p)
print("valor esperado:",E)
E2=np.sum((x**2)*p)
var=E2-E**2
print("Varianza:",var)
std=np.sqrt(var)
print("Desviacion estandar:",std)
F=np.cumsum(p)
print("F(x):",F)

plt.step(x,F,where="post")
plt.scatter(x,F)
plt.xlabel("Undiades vendidas")
plt.ylabel("F(x)")
plt.title("Distribucion acumulada de ventas")
plt.grid()
plt.show()
# Out:
# Suma de probabilidades: 1.0
# valor esperado: 7.9
# Varianza: 1.6899999999999906
# Desviacion estandar: 1.2999999999999965
# F(x): [0.05 0.15 0.35 0.65 0.9  1.  ]
